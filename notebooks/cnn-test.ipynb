# %%
import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.datasets import mnist
from tensorflow.keras.utils import to_categorical
#원-핫 변환 함수: 정답 숫자를 [0,0,...,1,...,0] 형태로 바꾸는 도구를 씁니다.

# 1. 데이터 불러오기
#왜 자동으로 나뉘어질까?
#mnist.load_data()는 Keras에 미리 정의된 MNIST 데이터셋 로더라서
(x_train, y_train), (x_test, y_test) = mnist.load_data()

# CNN 입력 형태에 맞게 reshape (28x28 → 28x28x1)
#(높이, 너비, 채널)
#-1 = 전체 개수 자동으로 맞춰라
x_train = x_train.reshape(-1, 28, 28, 1).astype("float32") / 255.0
x_test = x_test.reshape(-1, 28, 28, 1).astype("float32") / 255.0

# 라벨을 one-hot 인코딩(클래스 10으로 맞추기)
y_train = to_categorical(y_train, 10)
y_test = to_categorical(y_test, 10)

# 2. 모델 구성
model = tf.keras.Sequential([
    tf.keras.Input(shape=(28,28,1)),
    tf.keras.layers.Conv2D(32, (3,3), activation='relu'),
    layers.MaxPooling2D((2,2), padding='same'),
#ReLU로 음수는 0, 양수만 살립니다. 
#SAME 패딩으로 크기를 유지합니다(28×28 → 28×28).
#풀링(축소): 2×2 중 가장 큰 값만 남기며 크기를 절반으로 줄입니다.
 
    layers.Conv2D(64, (3,3), activation='relu', padding='same'),
    layers.MaxPooling2D((2,2), padding='same'),

    #펴기
    layers.Flatten(),
    layers.Dense(256, activation='relu'),
    #패턴 외우기 방지
    layers.Dropout(0.5),
    #결과 내기: 10개의 숫자에 대한 “확률”을 출력합니다. 가장 큰 값이 모델의 선택입니다.
    layers.Dense(10, activation='softmax')
])

# %%
# 3. 모델 컴파일
#Adam으로 똑똑하게 가중치 조정.
#categorical_crossentropy로 “정답과 예측의 차이”를 계산.
#accuracy(정확도)를 보고 학습이 잘 되는지 확인.

model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# 4. 학습
#→ 학습용 데이터(60,000장)를 여러 번 돌려보면서, 예측 확률이 정답에 더 가까워지도록 계속 수정합니다.
model.fit(x_train, y_train,
          batch_size=100,
          epochs=15,
          validation_data=(x_test, y_test))

# 5. 평가
test_loss, test_acc = model.evaluate(x_test, y_test, verbose=0)
print("최종 테스트 정확도:", test_acc)
# Out:
# Epoch 1/15
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 20s 29ms/step - accuracy: 0.9966 - loss: 0.0099 - val_accuracy: 0.9916 - val_loss: 0.0293
# Epoch 2/15
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 17s 28ms/step - accuracy: 0.9970 - loss: 0.0086 - val_accuracy: 0.9931 - val_loss: 0.0220
# Epoch 3/15
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 19s 32ms/step - accuracy: 0.9970 - loss: 0.0088 - val_accuracy: 0.9934 - val_loss: 0.0264
# Epoch 4/15
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 19s 31ms/step - accuracy: 0.9981 - loss: 0.0058 - val_accuracy: 0.9938 - val_loss: 0.0259
# Epoch 5/15
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 19s 32ms/step - accuracy: 0.9974 - loss: 0.0075 - val_accuracy: 0.9928 - val_loss: 0.0280
# Epoch 6/15
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 24s 38ms/step - accuracy: 0.9975 - loss: 0.0065 - val_accuracy: 0.9934 - val_loss: 0.0258
# Epoch 7/15
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 23s 39ms/step - accuracy: 0.9980 - loss: 0.0061 - val_accuracy: 0.9930 - val_loss: 0.0281
# Epoch 8/15
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 18s 29ms/step - accuracy: 0.9976 - loss: 0.0061 - val_accuracy: 0.9927 - val_loss: 0.0282
# Epoch 9/15
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 13s 22ms/step - accuracy: 0.9984 - loss: 0.0048 - val_accuracy: 0.9937 - val_loss: 0.0263
# Epoch 10/15
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 14s 23ms/step - accuracy: 0.9980 - loss: 0.0059 - val_accuracy: 0.9931 - val_loss: 0.0281
# Epoch 11/15
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 17s 29ms/step - accuracy: 0.9982 - loss: 0.0055 - val_accuracy: 0.9938 - val_loss: 0.0251
# Epoch 12/15
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 16s 27ms/step - accuracy: 0.9981 - loss: 0.0054 - val_accuracy: 0.9937 - val_loss: 0.0264
# Epoch 13/15
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 22s 30ms/step - accuracy: 0.9987 - loss: 0.0038 - val_accuracy: 0.9933 - val_loss: 0.0277
# Epoch 14/15
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 23s 33ms/step - accuracy: 0.9983 - loss: 0.0046 - val_accuracy: 0.9942 - val_loss: 0.0287
# Epoch 15/15
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 19s 32ms/step - accuracy: 0.9988 - loss: 0.0043 - val_accuracy: 0.9938 - val_loss: 0.0286
# 최종 테스트 정확도: 0.9937999844551086
